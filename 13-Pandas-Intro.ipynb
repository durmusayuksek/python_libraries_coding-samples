# %% [markdown]
# ### NOTES

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic_df = pd.DataFrame(titanic) # pandas dataframe'e donusturme islemi

# %%
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic_df.head() # dataframe'deki ilk 5 observation geliyor
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic_df.describe() # degiskenler hakkinda descriptive statistics'leri veriyor
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
# titanic_df.drop (['ticket', 'cabin'], axis = 1).head() drop komutu dataframe'den cikarmak istedigimiz degiskenleri icin

# %%
titanic_df.isnull().sum() # kactane null yani missing veri oldugunu gosteriyor
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
pd.value_counts(titanic_df['survived']).plot.bar()
# Out:
# <AxesSubplot:>

# %%
titanic_df.mean()
# Out:
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64

# %%
titanic_df['survived'].mean()
# Out:
# 0.3838383838383838

# %%
titanic_df.groupby(['sex']).mean()
# Out:
#         survived    pclass        age     sibsp     parch       fare  \
# sex
# female  0.742038  2.159236  27.915709  0.694268  0.649682  44.479818
# male    0.188908  2.389948  30.726645  0.429809  0.235702  25.523893
#
#         adult_male     alone
# sex
# female    0.000000  0.401274
# male      0.930676  0.712305

# %%
titanic_df.groupby(['sex','pclass']).mean()
# Out:
#                survived        age     sibsp     parch        fare  \
# sex    pclass
# female 1       0.968085  34.611765  0.553191  0.457447  106.125798
#        2       0.921053  28.722973  0.486842  0.605263   21.970121
#        3       0.500000  21.750000  0.895833  0.798611   16.118810
# male   1       0.368852  41.281386  0.311475  0.278689   67.226127
#        2       0.157407  30.740707  0.342593  0.222222   19.741782
#        3       0.135447  26.507589  0.498559  0.224784   12.661633
#
#                adult_male     alone
# sex    pclass
# female 1         0.000000  0.361702
#        2         0.000000  0.421053
#        3         0.000000  0.416667
# male   1         0.975410  0.614754
#        2         0.916667  0.666667
#        3         0.919308  0.760807

# %%
titanic_df[titanic_df['age']<18].groupby(['sex','pclass']).mean()
# Out:
#                survived        age     sibsp     parch        fare  \
# sex    pclass
# female 1       0.875000  14.125000  0.500000  0.875000  104.083337
#        2       1.000000   8.333333  0.583333  1.083333   26.241667
#        3       0.542857   8.428571  1.571429  1.057143   18.727977
# male   1       1.000000   8.230000  0.500000  2.000000  116.072900
#        2       0.818182   4.757273  0.727273  1.000000   25.659473
#        3       0.232558   9.963256  2.069767  1.000000   22.752523
#
#                adult_male     alone
# sex    pclass
# female 1         0.000000  0.125000
#        2         0.000000  0.166667
#        3         0.000000  0.228571
# male   1         0.250000  0.000000
#        2         0.181818  0.181818
#        3         0.348837  0.232558

# %%
###################################################################

# %%
import pandas as pd

# %%
series = pd.Series(('Nik', 'P', 30, 'nik@email.com', 175))

# %%
series
# Out:
# 0              Nik
# 1                P
# 2               30
# 3    nik@email.com
# 4              175
# dtype: object

# %%
dataframe1 = pd.DataFrame([('Nik', 'P', 30, 'nik@email.com', 175),('Evan', 'D', 31, 'evan@email.com', 170)])

# %%
dataframe1
# Out:
#       0  1   2               3    4
# 0   Nik  P  30   nik@email.com  175
# 1  Evan  D  31  evan@email.com  170

# %%
dataframe1 = pd.DataFrame([('Nik', 'P', 30, 'nik@email.com', 175),('Evan', 'D', 31, 'evan@email.com', 170)],
                         columns = ['First Name', 'Last Initial', 'Age', 'Email', 'Weight'])

# %%
dataframe1
# Out:
#   First Name Last Initial  Age           Email  Weight
# 0        Nik            P   30   nik@email.com     175
# 1       Evan            D   31  evan@email.com     170

# %%
dataframe2 = pd.DataFrame({'First Name':['Nik', 'Evan'], 'Last Initial':['P', 'D'],
                          'Age':[30, 31], 'Email':['nik@email.com', 'evan@email.com'], 'Weight': [175, 170]})

# %%
dataframe2
# Out:
#   First Name Last Initial  Age           Email  Weight
# 0        Nik            P   30   nik@email.com     175
# 1       Evan            D   31  evan@email.com     170

# %%
df = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/women-stem.csv') # bu sekilde data disaridan cekilebilir.

# %%
df
# Out:
#     Rank  Major_code                                          Major  \
# 0      1        2419                          PETROLEUM ENGINEERING
# 1      2        2416                 MINING AND MINERAL ENGINEERING
# 2      3        2415                      METALLURGICAL ENGINEERING
# 3      4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      5        2418                            NUCLEAR ENGINEERING
# ..   ...         ...                                            ...
# 71    72        3604                                        ECOLOGY
# 72    73        6109                  TREATMENT THERAPY PROFESSIONS
# 73    74        6100            GENERAL MEDICAL AND HEALTH SERVICES
# 74    75        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75    76        3609                                        ZOOLOGY
#
#             Major_category  Total    Men  Women  ShareWomen  Median
# 0              Engineering   2339   2057    282    0.120564  110000
# ...

# %%
df.shape
# Out:
# (76, 9)

# %%
df.head() # default 5'tir. Icine 10 yazarsam ilk 10 observation'i doner.
# Out:
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2418                        NUCLEAR ENGINEERING    Engineering
#
#    Total   Men  Women  ShareWomen  Median
# 0   2339  2057    282    0.120564  110000
# 1    756   679     77    0.101852   75000
# 2    856   725    131    0.153037   73000
# 3   1258  1123    135    0.107313   70000
# 4   2573  2200    373    0.144967   65000

# %%
df.tail() # ayni sekilde defaul 5. Son 5 observation'i donuyor.
# Out:
#     Rank  Major_code                                          Major  \
# 71    72        3604                                        ECOLOGY
# 72    73        6109                  TREATMENT THERAPY PROFESSIONS
# 73    74        6100            GENERAL MEDICAL AND HEALTH SERVICES
# 74    75        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75    76        3609                                        ZOOLOGY
#
#             Major_category  Total    Men  Women  ShareWomen  Median
# 71  Biology & Life Science   9154   3878   5276    0.576360   33000
# 72                  Health  48491  13487  35004    0.721866   33000
# 73                  Health  33599   7574  26025    0.774577   32400
# 74                  Health  38279   1225  37054    0.967998   28000
# 75  Biology & Life Science   8409   3050   5359    0.637293   26000

# %%
df.set_index('Major_code') # Major_code adli sutunu tablonun index'imiz haline getiriyor. Ancak gecici bir degisiklik
# Out:
#             Rank                                          Major  \
# Major_code
# 2419           1                          PETROLEUM ENGINEERING
# 2416           2                 MINING AND MINERAL ENGINEERING
# 2415           3                      METALLURGICAL ENGINEERING
# 2417           4      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 2418           5                            NUCLEAR ENGINEERING
# ...          ...                                            ...
# 3604          72                                        ECOLOGY
# 6109          73                  TREATMENT THERAPY PROFESSIONS
# 6100          74            GENERAL MEDICAL AND HEALTH SERVICES
# 6102          75  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 3609          76                                        ZOOLOGY
#
#                     Major_category  Total    Men  Women  ShareWomen  Median
# Major_code
# 2419                   Engineering   2339   2057    282    0.120564  110000
# ...

# %%
df.head()
# Out:
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2418                        NUCLEAR ENGINEERING    Engineering
#
#    Total   Men  Women  ShareWomen  Median
# 0   2339  2057    282    0.120564  110000
# 1    756   679     77    0.101852   75000
# 2    856   725    131    0.153037   73000
# 3   1258  1123    135    0.107313   70000
# 4   2573  2200    373    0.144967   65000

# %%
# Yeni index'in kalici olmasini istiyorsam
df = df.set_index('Major_code')

# %%
df.head()
# Out:
#             Rank                                      Major Major_category  \
# Major_code
# 2419           1                      PETROLEUM ENGINEERING    Engineering
# 2416           2             MINING AND MINERAL ENGINEERING    Engineering
# 2415           3                  METALLURGICAL ENGINEERING    Engineering
# 2417           4  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 2418           5                        NUCLEAR ENGINEERING    Engineering
#
#             Total   Men  Women  ShareWomen  Median
# Major_code
# 2419         2339  2057    282    0.120564  110000
# 2416          756   679     77    0.101852   75000
# 2415          856   725    131    0.153037   73000
# 2417         1258  1123    135    0.107313   70000
# 2418         2573  2200    373    0.144967   65000

# %%
# atama yapmadan yeni indexin kalici olmasini istiyorsak, bu sekilde yapilmali
df.set_index('Major_code', inplace = True)

# %%
df.head()
# Out:
#             Rank                                      Major Major_category  \
# Major_code
# 2419           1                      PETROLEUM ENGINEERING    Engineering
# 2416           2             MINING AND MINERAL ENGINEERING    Engineering
# 2415           3                  METALLURGICAL ENGINEERING    Engineering
# 2417           4  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 2418           5                        NUCLEAR ENGINEERING    Engineering
#
#             Total   Men  Women  ShareWomen  Median
# Major_code
# 2419         2339  2057    282    0.120564  110000
# 2416          756   679     77    0.101852   75000
# 2415          856   725    131    0.153037   73000
# 2417         1258  1123    135    0.107313   70000
# 2418         2573  2200    373    0.144967   65000

# %%
# herhangi bir column secmek icin
df.Major
# Out:
# Major_code
# 2419                            PETROLEUM ENGINEERING
# 2416                   MINING AND MINERAL ENGINEERING
# 2415                        METALLURGICAL ENGINEERING
# 2417        NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 2418                              NUCLEAR ENGINEERING
#                             ...
# 3604                                          ECOLOGY
# 6109                    TREATMENT THERAPY PROFESSIONS
# 6100              GENERAL MEDICAL AND HEALTH SERVICES
# 6102    COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 3609                                          ZOOLOGY
# Name: Major, Length: 76, dtype: object

# %%
df['Major'] # bu sekilde de column secilebiliyor. Bu daha fazla kullaniliyor.
# Out:
# Major_code
# 2419                            PETROLEUM ENGINEERING
# 2416                   MINING AND MINERAL ENGINEERING
# 2415                        METALLURGICAL ENGINEERING
# 2417        NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 2418                              NUCLEAR ENGINEERING
#                             ...
# 3604                                          ECOLOGY
# 6109                    TREATMENT THERAPY PROFESSIONS
# 6100              GENERAL MEDICAL AND HEALTH SERVICES
# 6102    COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 3609                                          ZOOLOGY
# Name: Major, Length: 76, dtype: object

# %%
df.loc[2419] # sadece bu index'teki observation ile ilgili bilgilere erismek icin kullaniliyor.
# Out:
# Rank                                  1
# Major             PETROLEUM ENGINEERING
# Major_category              Engineering
# Total                              2339
# Men                                2057
# Women                               282
# ShareWomen                     0.120564
# Median                           110000
# Name: 2419, dtype: object

# %%
df.loc[2419, 'Major']
# Out:
# 'PETROLEUM ENGINEERING'

# %%
df.iloc[0] # iloc'un loc'dan farki burada index numarasini bilmiyoruz. Bu durumda 0 ile ilk index'teki obs. secilir.
# Out:
# Rank                                  1
# Major             PETROLEUM ENGINEERING
# Major_category              Engineering
# Total                              2339
# Men                                2057
# Women                               282
# ShareWomen                     0.120564
# Median                           110000
# Name: 2419, dtype: object

# %%
df.iloc[0,1] # yani loc'ta label'lar kullanilirken, iloc'ta index numaralari kullaniliyor
# Out:
# 'PETROLEUM ENGINEERING'

# %%
df.iloc[0:5]
# Out:
#             Rank                                      Major Major_category  \
# Major_code
# 2419           1                      PETROLEUM ENGINEERING    Engineering
# 2416           2             MINING AND MINERAL ENGINEERING    Engineering
# 2415           3                  METALLURGICAL ENGINEERING    Engineering
# 2417           4  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 2418           5                        NUCLEAR ENGINEERING    Engineering
#
#             Total   Men  Women  ShareWomen  Median
# Major_code
# 2419         2339  2057    282    0.120564  110000
# 2416          756   679     77    0.101852   75000
# 2415          856   725    131    0.153037   73000
# 2417         1258  1123    135    0.107313   70000
# 2418         2573  2200    373    0.144967   65000

# %%
df.iloc[0:5, 1]
# Out:
# Major_code
# 2419                        PETROLEUM ENGINEERING
# 2416               MINING AND MINERAL ENGINEERING
# 2415                    METALLURGICAL ENGINEERING
# 2417    NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 2418                          NUCLEAR ENGINEERING
# Name: Major, dtype: object

# %%
df.iloc[-5:] # son 5 observation
# Out:
#             Rank                                          Major  \
# Major_code
# 3604          72                                        ECOLOGY
# 6109          73                  TREATMENT THERAPY PROFESSIONS
# 6100          74            GENERAL MEDICAL AND HEALTH SERVICES
# 6102          75  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 3609          76                                        ZOOLOGY
#
#                     Major_category  Total    Men  Women  ShareWomen  Median
# Major_code
# 3604        Biology & Life Science   9154   3878   5276    0.576360   33000
# 6109                        Health  48491  13487  35004    0.721866   33000
# 6100                        Health  33599   7574  26025    0.774577   32400
# 6102                        Health  38279   1225  37054    0.967998   28000
# 3609        Biology & Life Science   8409   3050   5359    0.637293   26000

# %%
df.iloc[:5, :3]
# Out:
#             Rank                                      Major Major_category
# Major_code
# 2419           1                      PETROLEUM ENGINEERING    Engineering
# 2416           2             MINING AND MINERAL ENGINEERING    Engineering
# 2415           3                  METALLURGICAL ENGINEERING    Engineering
# 2417           4  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 2418           5                        NUCLEAR ENGINEERING    Engineering

# %%
df['Major'] == 'ECOLOGY'
# Out:
# Major_code
# 2419    False
# 2416    False
# 2415    False
# 2417    False
# 2418    False
#         ...
# 3604     True
# 6109    False
# 6100    False
# 6102    False
# 3609    False
# Name: Major, Length: 76, dtype: bool

# %%
df[df['Major'] == 'ECOLOGY']
# Out:
#             Rank    Major          Major_category  Total   Men  Women  \
# Major_code
# 3604          72  ECOLOGY  Biology & Life Science   9154  3878   5276
#
#             ShareWomen  Median
# Major_code
# 3604           0.57636   33000

# %%
df.loc[df['Major'] == 'ECOLOGY']
# Out:
#             Rank    Major          Major_category  Total   Men  Women  \
# Major_code
# 3604          72  ECOLOGY  Biology & Life Science   9154  3878   5276
#
#             ShareWomen  Median
# Major_code
# 3604           0.57636   33000

# %%
df[df['ShareWomen'] > 0.50]
# Out:
#             Rank                                              Major  \
# Major_code
# 5001           7                         ASTRONOMY AND ASTROPHYSICS
# 6107          27                                            NURSING
# 5102          29  NUCLEAR, INDUSTRIAL RADIOLOGY, AND BIOLOGICAL ...
# 3702          35                    STATISTICS AND DECISION SCIENCE
# 3607          36                                       PHARMACOLOGY
# 6105          37                   MEDICAL TECHNOLOGIES TECHNICIANS
# 5006          38                                       OCEANOGRAPHY
# 6104          41                         MEDICAL ASSISTING SERVICES
# 4006          43                COGNITIVE SCIENCE AND BIOPSYCHOLOGY
# 3605          48                                           GENETICS
# 3603          49                                  MOLECULAR BIOLOGY
# 6108          50  PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTR...
# 5003          51                                          CHEMISTRY
# ...

# %%
df[(df['ShareWomen'] > 0.5) & (df['Major_category'] == 'Biology & Life Science')] 
# and icin & kullaniliyor
# Out:
#             Rank                                Major          Major_category  \
# Major_code
# 3607          36                         PHARMACOLOGY  Biology & Life Science
# 4006          43  COGNITIVE SCIENCE AND BIOPSYCHOLOGY  Biology & Life Science
# 3605          48                             GENETICS  Biology & Life Science
# 3603          49                    MOLECULAR BIOLOGY  Biology & Life Science
# 3606          52                         MICROBIOLOGY  Biology & Life Science
# 3601          54                 BIOCHEMICAL SCIENCES  Biology & Life Science
# 3602          55                               BOTANY  Biology & Life Science
# 1301          60                ENVIRONMENTAL SCIENCE  Biology & Life Science
# 3608          64                           PHYSIOLOGY  Biology & Life Science
# 3611          65                         NEUROSCIENCE  Biology & Life Science
# 3699          69                MISCELLANEOUS BIOLOGY  Biology & Life Science
# ...

# %%
df[(df['ShareWomen'] > 0.5) | (df['Major_category'] == 'Biology & Life Science')] 
# or icin | kullaniliyor
# Out:
#             Rank                                              Major  \
# Major_code
# 5001           7                         ASTRONOMY AND ASTROPHYSICS
# 6107          27                                            NURSING
# 5102          29  NUCLEAR, INDUSTRIAL RADIOLOGY, AND BIOLOGICAL ...
# 3702          35                    STATISTICS AND DECISION SCIENCE
# 3607          36                                       PHARMACOLOGY
# 6105          37                   MEDICAL TECHNOLOGIES TECHNICIANS
# 5006          38                                       OCEANOGRAPHY
# 6104          41                         MEDICAL ASSISTING SERVICES
# 4006          43                COGNITIVE SCIENCE AND BIOPSYCHOLOGY
# 3605          48                                           GENETICS
# 3603          49                                  MOLECULAR BIOLOGY
# 6108          50  PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTR...
# 5003          51                                          CHEMISTRY
# ...

# %%
# df[(df['Major_category'] == 'Health') | (df['Major_category'] == 'Biology & Life Science')]
df[df['Major_category'].isin (['Health', 'Biology & Life Science'])]
# Out:
#             Rank                                              Major  \
# Major_code
# 6107          27                                            NURSING
# 3607          36                                       PHARMACOLOGY
# 6105          37                   MEDICAL TECHNOLOGIES TECHNICIANS
# 6104          41                         MEDICAL ASSISTING SERVICES
# 4006          43                COGNITIVE SCIENCE AND BIOPSYCHOLOGY
# 3605          48                                           GENETICS
# 3603          49                                  MOLECULAR BIOLOGY
# 6108          50  PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTR...
# 3606          52                                       MICROBIOLOGY
# 3601          54                               BIOCHEMICAL SCIENCES
# 3602          55                                             BOTANY
# 6199          59           MISCELLANEOUS HEALTH MEDICAL PROFESSIONS
# 1301          60                              ENVIRONMENTAL SCIENCE
# ...

# %%
df[(df['Major_category'].isin (['Health', 'Biology & Life Science'])) | (df['ShareWomen'] < 0.5)]
# Out:
#             Rank                                          Major  \
# Major_code
# 2419           1                          PETROLEUM ENGINEERING
# 2416           2                 MINING AND MINERAL ENGINEERING
# 2415           3                      METALLURGICAL ENGINEERING
# 2417           4      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 2418           5                            NUCLEAR ENGINEERING
# ...          ...                                            ...
# 3604          72                                        ECOLOGY
# 6109          73                  TREATMENT THERAPY PROFESSIONS
# 6100          74            GENERAL MEDICAL AND HEALTH SERVICES
# 6102          75  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 3609          76                                        ZOOLOGY
#
#                     Major_category  Total    Men  Women  ShareWomen  Median
# Major_code
# 2419                   Engineering   2339   2057    282    0.120564  110000
# ...

# %%
df[['Major', 'Total']]
# Out:
#                                                     Major  Total
# Major_code
# 2419                                PETROLEUM ENGINEERING   2339
# 2416                       MINING AND MINERAL ENGINEERING    756
# 2415                            METALLURGICAL ENGINEERING    856
# 2417            NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258
# 2418                                  NUCLEAR ENGINEERING   2573
# ...                                                   ...    ...
# 3604                                              ECOLOGY   9154
# 6109                        TREATMENT THERAPY PROFESSIONS  48491
# 6100                  GENERAL MEDICAL AND HEALTH SERVICES  33599
# 6102        COMMUNICATION DISORDERS SCIENCES AND SERVICES  38279
# 3609                                              ZOOLOGY   8409
#
# [76 rows x 2 columns]

# %%
df.info() # genel bilgi almak icin
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            76 non-null     int64
#  1   Major_code      76 non-null     int64
#  2   Major           76 non-null     object
#  3   Major_category  76 non-null     object
#  4   Total           76 non-null     int64
#  5   Men             76 non-null     int64
#  6   Women           76 non-null     int64
#  7   ShareWomen      76 non-null     float64
#  8   Median          76 non-null     int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 5.5+ KB

# %%
df.describe() # descriptive statistics
# Out:
#             Rank   Major_code          Total            Men          Women  \
# count  76.000000    76.000000      76.000000      76.000000      76.000000
# mean   38.500000  3580.026316   25515.289474   12800.763158   12714.526316
# std    22.083176  1437.455038   43998.008553   21307.554101   29056.014723
# min     1.000000  1301.000000     609.000000     488.000000      77.000000
# 25%    19.750000  2409.750000    3782.000000    2047.750000    1227.500000
# 50%    38.500000  3601.500000   11047.500000    4583.000000    5217.500000
# 75%    57.250000  5002.250000   27509.250000   11686.500000   12463.500000
# max    76.000000  6199.000000  280709.000000  111762.000000  187621.000000
#
#        ShareWomen         Median
# count   76.000000      76.000000
# mean     0.436929   46118.421053
# std      0.232176   13187.223216
# min      0.077453   26000.000000
# 25%      0.247918   36150.000000
# 50%      0.405868   44350.000000
# 75%      0.591803   52250.000000
# ...

# %%
df['Major_code'].describe()
# Out:
# count      76.000000
# mean     3580.026316
# std      1437.455038
# min      1301.000000
# 25%      2409.750000
# 50%      3601.500000
# 75%      5002.250000
# max      6199.000000
# Name: Major_code, dtype: float64

# %%
df['Major_category'].value_counts()
# Out:
# Engineering                29
# Biology & Life Science     14
# Health                     12
# Computers & Mathematics    11
# Physical Sciences          10
# Name: Major_category, dtype: int64

# %%
df['Major_category'].value_counts(normalize = True) # bu durumda percentage'larini veriyor
# Out:
# Engineering                0.381579
# Biology & Life Science     0.184211
# Health                     0.157895
# Computers & Mathematics    0.144737
# Physical Sciences          0.131579
# Name: Major_category, dtype: float64

# %%
df['ShareWomen'].mean()
# Out:
# 0.43692924057894733

# %%
df['ShareWomen'].loc[df['Major_category'] == 'Engineering'].mean()
# Out:
# 0.23888867596551722

# %%
df['Major_category'].unique() # Major_category column'undaki unique degerleri array olarak doner.
# Out:
# array(['Engineering', 'Physical Sciences', 'Computers & Mathematics',
#        'Health', 'Biology & Life Science'], dtype=object)

# %%
df['Major_category'].unique().tolist() # bu sekilde array'i listeye donusturebilirsin
# Out:
# ['Engineering',
#  'Physical Sciences',
#  'Computers & Mathematics',
#  'Health',
#  'Biology & Life Science']

# %%
df.columns # dataframe icerisindeki sutunlari verir
# Out:
# Index(['Rank', 'Major_code', 'Major', 'Major_category', 'Total', 'Men',
#        'Women', 'ShareWomen', 'Median'],
#       dtype='object')

# %%
import numpy as np
df.iloc[50:55, 3] = np.NaN # dataframe'in 3'uncu sutununun 50 ile 55 arasindaki row'larina Null atamasi yaptik

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            76 non-null     int64
#  1   Major_code      76 non-null     int64
#  2   Major           76 non-null     object
#  3   Major_category  71 non-null     object
#  4   Total           76 non-null     int64
#  5   Men             76 non-null     int64
#  6   Women           76 non-null     int64
#  7   ShareWomen      76 non-null     float64
#  8   Median          76 non-null     int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 5.5+ KB

# %%
df.isnull() # herhangi bir cell'deki data'nin null olup olmadigini soyluyor
# Out:
#      Rank  Major_code  Major  Major_category  Total    Men  Women  ShareWomen  \
# 0   False       False  False           False  False  False  False       False
# 1   False       False  False           False  False  False  False       False
# 2   False       False  False           False  False  False  False       False
# 3   False       False  False           False  False  False  False       False
# 4   False       False  False           False  False  False  False       False
# ..    ...         ...    ...             ...    ...    ...    ...         ...
# 71  False       False  False           False  False  False  False       False
# 72  False       False  False           False  False  False  False       False
# 73  False       False  False           False  False  False  False       False
# 74  False       False  False           False  False  False  False       False
# 75  False       False  False           False  False  False  False       False
#
#     Median
# 0    False
# ...

# %%
df.isnull().sum() # isnull'daki True'lar 1 sayilacak ve False'lar 0 sayilacagi icin bize null olanlarin sayilarini verecek.
# Out:
# Rank              0
# Major_code        0
# Major             0
# Major_category    5
# Total             0
# Men               0
# Women             0
# ShareWomen        0
# Median            0
# dtype: int64

# %%
len(df) # row sayisini verir
# Out:
# 76

# %%
len(df['Women']) # Women column'undaki row sayisini veriyor
# Out:
# 76

# %%
df.isnull().value_counts(normalize = True)
# Out:
# Rank   Major_code  Major  Major_category  Total  Men    Women  ShareWomen  Median
# False  False       False  False           False  False  False  False       False     0.934211
#                           True            False  False  False  False       False     0.065789
# dtype: float64

# %%
data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'B', 'B', 'A', 'A'],
    'city' :    [ 'Gurgaon', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', 'blue', 'yellow', 'pink', 'black', 'green', 'red']
})

data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F            blue
# 2   13       C   Mumbai      F          yellow
# 3   21       B    Delhi      M            pink
# 4   12       B   Mumbai      M           black
# 5   11       A    Delhi      M           green
# 6   17       A   Mumbai      F             red

# %%
data['new'] = data['city'].str[:2]

# %%
data
# Out:
#    age section     city gender favourite_color new
# 0   10       A  Gurgaon      M             red  Gu
# 1   22       B    Delhi      F            blue  De
# 2   13       C   Mumbai      F          yellow  Mu
# 3   21       B    Delhi      M            pink  De
# 4   12       B   Mumbai      M           black  Mu
# 5   11       A    Delhi      M           green  De
# 6   17       A   Mumbai      F             red  Mu

# %%
data.drop(6, axis=0, inplace=True)

# %%
data
# Out:
#    age section     city gender favourite_color new
# 0   10       A  Gurgaon      M             red  Gu
# 1   22       B    Delhi      F            blue  De
# 2   13       C   Mumbai      F          yellow  Mu
# 3   21       B    Delhi      M            pink  De
# 4   12       B   Mumbai      M           black  Mu
# 5   11       A    Delhi      M           green  De

# %%
data.iloc[1]
# Out:
# age                   22
# section                B
# city               Delhi
# gender                 F
# favourite_color     blue
# new                   De
# Name: 1, dtype: object

# %%
data.loc[[0,2],['age','city']]
# Out:
#    age     city
# 0   10  Gurgaon
# 2   13   Mumbai

# %%
data.iloc[[3,4], [1,2]]
# Out:
#   section    city
# 3       B   Delhi
# 4       B  Mumbai

# %%
data.iloc[3:5, 1:3]
# Out:
#   section    city
# 3       B   Delhi
# 4       B  Mumbai

# %%
data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'D', 'E', 'F', 'G'],
    'country' : [ 'USA', 'GBR', 'TUR', 'NLD', 'BEL', 'DEU', 'FRA'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', 'blue', 'yellow', 'pink', 'black', 'green', 'red']
})
data.set_index('section', inplace=True)
data
# Out:
#          age country gender favourite_color
# section
# A         10     USA      M             red
# B         22     GBR      F            blue
# C         13     TUR      F          yellow
# D         21     NLD      M            pink
# E         12     BEL      M           black
# F         11     DEU      M           green
# G         17     FRA      F             red

# %%
data[data['age'] > 15]
# Out:
#          age country gender favourite_color
# section
# B         22     GBR      F            blue
# D         21     NLD      M            pink
# G         17     FRA      F             red

# %%
data['country'].loc[data['age'] > 15]
# Out:
# section
# B    GBR
# D    NLD
# G    FRA
# Name: country, dtype: object

# %%
data['country'][data['age'] > 15]
# Out:
# section
# B    GBR
# D    NLD
# G    FRA
# Name: country, dtype: object

# %%
data[data['age'] > 15]['country']
# Out:
# section
# B    GBR
# D    NLD
# G    FRA
# Name: country, dtype: object

# %%
data[(data['favourite_color'] == 'red') & (data['age'] > 15)]
# Out:
#          age country gender favourite_color
# section
# G         17     FRA      F             red

# %%
data[(data['age']>20) | (data['favourite_color'] == 'red')]
# Out:
#          age country gender favourite_color
# section
# A         10     USA      M             red
# B         22     GBR      F            blue
# D         21     NLD      M            pink
# G         17     FRA      F             red

# %%
outside = ['A1','A1','A1','A2','A2','A2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)
np.random.seed(101)
data = pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['X','Y'])
data
# Out:
#              X         Y
# A1 1  2.706850  0.628133
#    2  0.907969  0.503826
#    3  0.651118 -0.319318
# A2 1 -0.848077  0.605965
#    2 -2.018168  0.740122
#    3  0.528813 -0.589001

# %%
data['Y']['A2']
# Out:
# 1    0.605965
# 2    0.740122
# 3   -0.589001
# Name: Y, dtype: float64

# %%
data.loc['A1','X']
# Out:
# 1    2.706850
# 2    0.907969
# 3    0.651118
# Name: X, dtype: float64

# %%
 data['X']['A1']
# Out:
# 1    2.706850
# 2    0.907969
# 3    0.651118
# Name: X, dtype: float64

# %%
data.loc['A2'].loc[1, 'Y']
# Out:
# 0.6059653494949336
