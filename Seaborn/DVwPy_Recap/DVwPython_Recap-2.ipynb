# %% [markdown]
# ## Seaborn and Matplotlib

# %%
########################################################
## Importing Library
########################################################

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
########################################################
## Check Version
########################################################


print(plt.matplotlib.__version__)
# Out:
# 3.3.2

# %%
age = [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45]
salary = [38496, 42000, 46752, 49320, 53200, 56000, 62316, 64928, 67317, 68748, 73752]

# %%
#  DataFrame.plot.line(x=None, y=None, **kwds)

# %%
########################################################
## Basic Line Plot with Pandas
########################################################

df = pd.DataFrame({"age" : [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45], 
    "salary" : [38496, 42000, 46752, 49320, 53200, 56000, 62316, 64928, 67317, 68748, 73752]
    }, index=[25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45])

df.head()
# Out:
#     age  salary
# 25   25   38496
# 27   27   42000
# 29   29   46752
# 31   31   49320
# 33   33   53200

# %%
lines = df.plot.line(x='age', y='salary', color = "red")

# %%
########################################################
## Basic Line Plot with Matplotlib
########################################################
plt.plot(age,salary)
plt.show()

# %%
# functional method
plt.plot(age, salary)

plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Salary by Age")
plt.show()

# %%
fig, ax = plt.subplots()

ax.plot(age,salary, "r")

ax.set_xlabel("Age")
ax.set_ylabel('Salary')
ax.set_title("Salary by Age")
plt.show()

# %%
plt.subplot(2,3,1)
plt.plot()
plt.subplot(2,3,2)
plt.plot()
plt.subplot(2,3,3)
plt.plot()
plt.subplot(2,3,4)
plt.plot()
plt.subplot(2,3,5)
plt.plot()
plt.subplot(2,3,6)
plt.plot()
plt.tight_layout()

# %%
salary_2 = [45372, 48876, 53850, 57287, 63016,65998, 70003, 70000, 71496, 75370, 83640]

# %%
# functional
plt.subplot(2,1,1)
plt.plot(age, salary, "r")
plt.xlabel("Age vs Salary1")

plt.subplot(2,1,2)
plt.plot(age, salary_2, "b")
plt.xlabel("Age vs Salary2")

plt.tight_layout()
plt.show()

# %%
# functional
plt.subplot(211)
plt.plot(age, salary, "r")
plt.xlabel("Age vs Salary1")

plt.subplot(211)
plt.plot(age, salary_2, "b")
plt.xlabel("Age vs Salary2")

plt.tight_layout()
plt.show()
# Out:
# /var/folders/_5/jffz5k3x7s9bn8g2q5hhys_80000gn/T/ipykernel_21773/1092611782.py:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(211)

# %%
plt.plot(age, salary, color= "green")
plt.plot(age, salary_2)

plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Salary by Age");
plt.show()

# %%
x = np.arange(1,11)
y = x.copy()
z = x*2
t = np.log(x)

# %%
fig, ax = plt.subplots(2,3)

ax[1,1].plot(x,y)

ax[0,2].plot(x,x**2)

plt.tight_layout()
plt.show()

# %%
plt.subplot(2,2,1)
plt.plot(age, salary, "r+")

plt.subplot(2,2,2)
plt.plot(age, salary, "b--")

plt.subplot(2,2,3)
plt.plot(age, salary, "mo")

plt.subplot(2,2,4)
plt.plot(age, salary, "c.")
plt.tight_layout()

# %%
plt.plot(age, salary, label="salary")
plt.plot(age, salary_2, label="salary_2")

plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Salary by Age")

plt.axvline(x=np.mean(age), ymin=0, ymax=90000, ls="--")
plt.axhline(y=np.mean(salary), xmin=0, xmax=50, ls=":")
plt.axhline(y=np.mean(salary_2), xmin=0, xmax=50, ls="-.")

plt.legend(loc=0);

plt.show()

# %%
plt.plot(age, salary, label="salary")
plt.plot(age, salary_2, label="salary_2")
plt.xlabel("age")
plt.ylabel("Salary")
plt.title("Salary by Age")
plt.axvline(x=35.5, ymin=0, ymax=90000, ls="--")
plt.axhline(y=60000, xmin=0, xmax=45, ls="--")
plt.legend(loc=0);
plt.show()

# %%
x = np.arange(1,10)
fig, ax = plt.subplots(nrows=1,ncols=2, figsize=(10,4))

ax[0].plot(x,x**2, x,x**3, x,x**4)

ax[1].plot(x,x**2, x,x**3, x,x**4)
ax[1].set_xlim([2,4])
ax[1].set_ylim([5,100])

ax[0].axvline(x=3,ls="--")
ax[0].axhline(y=50,ls="--")

ax[1].axvline(x=3,ls="--")
ax[1].axhline(y=50,ls="--")

plt.show()

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.scatter(tips["tip"], tips["total_bill"]);

# %%
day = tips.groupby("day")["total_bill"].sum()
day
# Out:
# day
# Thur    1096.33
# Fri      325.88
# Sat     1778.40
# Sun     1627.16
# Name: total_bill, dtype: float64

# %%
plt.bar(day.index, day.values)
plt.show()

# %%
sex = tips.groupby("sex")["total_bill"].sum().index
tip = tips.groupby("sex")["tip"].sum()

# %%
fig, ax = plt.subplots()

ax.bar(sex,tip)
plt.show()

# %%
day = tips.groupby("day")["total_bill"].sum().index
tip = tips.groupby("day")["tip"].sum()
total = tips.groupby("day")["total_bill"].sum()


fig, ax = plt.subplots()

ax.bar(day, total, label="total" )
ax.bar(day, tip, label="tip" )


plt.legend()
plt.show()

# %%
day = tips.groupby("day")["total_bill"].sum().index
tip = tips.groupby("day")["tip"].sum()
total = tips.groupby("day")["total_bill"].sum()

x = np.arange(len(day))
width = 0.35
fig, ax = plt.subplots()

ax.bar(x-width/2, total, width, label="total" )
ax.bar(x+width/2, tip,   width, label="tip" )

ax.set_xticks(x)
ax.set_xticklabels(day)

plt.legend()
plt.show()

# %%
day = tips.groupby("day")["total_bill"].sum().index
tip = tips.groupby("day")["tip"].sum()
total = tips.groupby("day")["total_bill"].sum()

x = np.arange(len(day))
width = 0.35
fig, ax = plt.subplots()

ax.bar(x, total, width, label="total" )
ax.bar(x+width, tip, width, label="tip" )

ax.set_xticks(x)
ax.set_xticklabels(day)

plt.legend()
plt.show()

# %%
plt.hist(tips['tip'], bins=100)
plt.show()

# %%
plt.figure(figsize=(6,4))

plt.boxplot(tips["total_bill"], vert=False)
plt.show()

# %%
plt.figure(figsize=(16,6))

plt.boxplot([tips.tip, tips.total_bill], vert=False) # ayni axes icinde iki boxplot
plt.show()

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %% [markdown]
# ## Seaborn

# %%
plt.figure(figsize=(14,4))

sns.scatterplot(x='total_bill', y='tip', data=tips);

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips, hue= "sex", style="sex", size='sex');

# %%
sns.scatterplot(x="total_bill",y="tip",data=tips, hue="sex", s=100, alpha = 0.5);

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=tips["total_bill"],y='tip', data=tips,style='sex',hue='sex',s=100);

# Call savefig in the same cell
# plt.savefig('example_scatter.jpg')

# %%
sns.displot(x='total_bill', data=tips, kde = True, bins=50);

# %%
sns.distplot(x=tips.total_bill, kde = True, bins=50);
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.histplot(data = tips, x = 'total_bill', bins=50, kde=True)  ;
