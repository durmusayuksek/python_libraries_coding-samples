# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %% [markdown]
# ## Text Methods

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['sex'].str.islower().sum()
# Out:
# 891

# %%
df.sex.shape
# Out:
# (891,)

# %%
df.sex.str.contains('male')
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 886    True
# 887    True
# 888    True
# 889    True
# 890    True
# Name: sex, Length: 891, dtype: bool

# %%
df.sex.str.contains('female')
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: sex, Length: 891, dtype: bool

# %%
df.sex.str.contains('female').sum()
# Out:
# 314

# %%
df[df.sex.str.contains('female')]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.sex = df.sex.str.upper()

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    MALE  22.0      1      0   7.2500        S   Third
# 1           1       1  FEMALE  38.0      1      0  71.2833        C   First
# 2           1       3  FEMALE  26.0      0      0   7.9250        S   Third
# 3           1       1  FEMALE  35.0      1      0  53.1000        S   First
# 4           0       3    MALE  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    MALE  27.0      0      0  13.0000        S  Second
# 887         1       1  FEMALE  19.0      0      0  30.0000        S   First
# 888         0       3  FEMALE   NaN      1      2  23.4500        S   Third
# 889         1       1    MALE  26.0      0      0  30.0000        C   First
# 890         0       3    MALE  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.sex.apply(lambda x : x.lower() if x == 'MALE' else x)
# Out:
# 0        male
# 1      FEMALE
# 2      FEMALE
# 3      FEMALE
# 4        male
#         ...
# 886      male
# 887    FEMALE
# 888    FEMALE
# 889      male
# 890      male
# Name: sex, Length: 891, dtype: object

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    MALE  22.0      1      0   7.2500        S   Third
# 1           1       1  FEMALE  38.0      1      0  71.2833        C   First
# 2           1       3  FEMALE  26.0      0      0   7.9250        S   Third
# 3           1       1  FEMALE  35.0      1      0  53.1000        S   First
# 4           0       3    MALE  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    MALE  27.0      0      0  13.0000        S  Second
# 887         1       1  FEMALE  19.0      0      0  30.0000        S   First
# 888         0       3  FEMALE   NaN      1      2  23.4500        S   Third
# 889         1       1    MALE  26.0      0      0  30.0000        C   First
# 890         0       3    MALE  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['class'] = df['class'].str.swapcase()

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    MALE  22.0      1      0   7.2500        S   tHIRD
# 1           1       1  FEMALE  38.0      1      0  71.2833        C   fIRST
# 2           1       3  FEMALE  26.0      0      0   7.9250        S   tHIRD
# 3           1       1  FEMALE  35.0      1      0  53.1000        S   fIRST
# 4           0       3    MALE  35.0      0      0   8.0500        S   tHIRD
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    MALE  27.0      0      0  13.0000        S  sECOND
# 887         1       1  FEMALE  19.0      0      0  30.0000        S   fIRST
# 888         0       3  FEMALE   NaN      1      2  23.4500        S   tHIRD
# 889         1       1    MALE  26.0      0      0  30.0000        C   fIRST
# 890         0       3    MALE  32.0      0      0   7.7500        Q   tHIRD
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['age'].astype('string').str.isnumeric()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     <NA>
# 889    False
# 890    False
# Name: age, Length: 891, dtype: boolean

# %%
df.age = df.age.replace(np.nan, 'unk')

# %%
df.age.value_counts()
# Out:
# unk     177
# 24.0     30
# 22.0     27
# 18.0     26
# 28.0     25
#        ...
# 70.5      1
# 0.42      1
# 66.0      1
# 53.0      1
# 34.5      1
# Name: age, Length: 89, dtype: int64

# %%
df.embark_town.str.contains('bourg')
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889     True
# 890    False
# Name: embark_town, Length: 891, dtype: object

# %%
# str metodu kullanacagimiz bir sutunda nan value varsa filtering yapamayiz
# once nan'lari doldurmamiz gerekiyor filtering yapmak icin

# %%
df[df.age.astype('string').str.contains('2')]
# Out:
#      survived  pclass     sex age  sibsp  parch     fare embarked   class  \
# 0           0       3    MALE  22      1      0   7.2500        S   Third
# 2           1       3  FEMALE  26      0      0   7.9250        S   Third
# 7           0       3    MALE   2      3      1  21.0750        S   Third
# 8           1       3  FEMALE  27      0      2  11.1333        S   Third
# 12          0       3    MALE  20      0      0   8.0500        S   Third
# ..        ...     ...     ...  ..    ...    ...      ...      ...     ...
# 883         0       2    MALE  28      0      0  10.5000        S  Second
# 884         0       3    MALE  25      0      0   7.0500        S   Third
# 886         0       2    MALE  27      0      0  13.0000        S  Second
# 889         1       1    MALE  26      0      0  30.0000        C   First
# 890         0       3    MALE  32      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.age.astype('string').str.find('unk')
# 0 donen yer unk'nin oldugu yer, -1 olmadigi yerler
# Out:
# 0      -1
# 1      -1
# 2      -1
# 3      -1
# 4      -1
#        ..
# 886    -1
# 887    -1
# 888     0
# 889    -1
# 890    -1
# Name: age, Length: 891, dtype: Int64

# %%
df.embark_town.str.findall('bourg').value_count
# Out:
# <bound method Series.count of 0           []
# 1      [bourg]
# 2           []
# 3           []
# 4           []
#         ...
# 886         []
# 887         []
# 888         []
# 889    [bourg]
# 890         []
# Name: embark_town, Length: 891, dtype: object>

# %% [markdown]
# ## Datetime

# %%
flight = sns.load_dataset('flights')

# %%
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flight.year = pd.to_datetime(flight.year, format = '%Y', errors= 'ignore')

# %%
flight.year
# Out:
# 0     1949-01-01
# 1     1949-01-01
# 2     1949-01-01
# 3     1949-01-01
# 4     1949-01-01
#          ...
# 139   1960-01-01
# 140   1960-01-01
# 141   1960-01-01
# 142   1960-01-01
# 143   1960-01-01
# Name: year, Length: 144, dtype: datetime64[ns]

# %%
from datetime import datetime

# %%
flight.year.dt.month_name()
# Out:
# 0      January
# 1      January
# 2      January
# 3      January
# 4      January
#         ...
# 139    January
# 140    January
# 141    January
# 142    January
# 143    January
# Name: year, Length: 144, dtype: object

# %%
current_time = datetime.now()
current_time
# Out:
# datetime.datetime(2021, 10, 9, 11, 43, 22, 872535)

# %%
print(current_time)
# Out:
# 2021-10-09 11:43:22.872535

# %%
current_time.date()
# Out:
# datetime.date(2021, 10, 9)

# %%
current_time.hour
# Out:
# 11

# %%
current_time.month
# Out:
# 10

# %%
datee = current_time.strftime('%d %B %Y')
datee
# Out:
# '09 October 2021'

# %%
current_time.strftime(('%d ' + '%B ' + '%Y'))
# Out:
# '09 October 2021'

# %%
datetime.strptime(datee, '%d %B %Y')
# Out:
# datetime.datetime(2021, 10, 9, 0, 0)

# %%
# strftime datetime bir date'i formatlamaya yarar
# strptime string bir date'i parcalamaya yarar

# %%
from datetime import timedelta

# %%
current_time
# Out:
# datetime.datetime(2021, 10, 9, 11, 43, 22, 872535)

# %%
current_time + timedelta(weeks= 2)
# Out:
# datetime.datetime(2021, 10, 23, 11, 43, 22, 872535)

# %%
current_time.now()
# Out:
# datetime.datetime(2021, 10, 9, 12, 14, 0, 128134)

# %%
current_time.now() + timedelta(days = 1)
# Out:
# datetime.datetime(2021, 10, 10, 12, 14, 1, 442211)

# %%
(current_time.now() + timedelta(days = 1)).strftime('%d %B %Y')
# Out:
# '10 October 2021'

# %% [markdown]
# ## Data Input Output

# %%
df = pd.read_csv('example.csv')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df2 = pd.read_csv('example.csv', usecols = ['a', 'b'])

# %%
df2
# Out:
#     a   b
# 0   0   1
# 1   4   5
# 2   8   9
# 3  12  13

# %%
titanic = pd.read_csv('titanic_train.csv', nrows=10)

# %%
titanic
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
pd.read_csv('ornekcsv.csv', sep=';')
# Out:
#       a    b     c
# 0    78   12   1.0
# 1    78   12   2.0
# 2    78  324   3.0
# 3     7    2   4.0
# 4    88   23   5.0
# 5     6    2   NaN
# 6    56   11   6.0
# 7     7   12   7.0
# 8    56   21   7.0
# 9   346    2   8.0
# 10    5    1   8.0
# 11  456   21   8.0
# 12    3   12  88.0

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('write_csv1')

# %%
pwd
# Out:
# '/Users/intuition/Desktop/CLARUSWAY/DS-PATH/2-DA with Python/Pandas'

# %%
df.to_csv('/Users/intuition/Desktop/write_csv1')

# %% [markdown]
# ### Excel

# %%
import pandas as pd

# %%
df3 = pd.read_excel('Excel_Sample.xlsx')
df3
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df3.to_excel('excel1.xlsx', sheet_name='sh1', index=False)

# %%
df3.to_excel('excel2.xlsx', sheet_name='sh2')

# %%
df = pd.read_excel('excel1.xlsx')
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df = pd.read_excel('excel2.xlsx')
df
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
with pd.ExcelWriter('combined.xlsx') as writer:
    df.to_excel(writer, sheet_name='sh1', index=False)
    df.to_excel(writer, sheet_name='sh2', index=True)

# %%
df = pd.read_excel('combined.xlsx',sheet_name='sh2')
df
# Out:
#    Unnamed: 0  Unnamed: 0.1   a   b   c   d
# 0           0             0   0   1   2   3
# 1           1             1   4   5   6   7
# 2           2             2   8   9  10  11
# 3           3             3  12  13  14  15

# %% [markdown]
# ### HTML

# %%
pd11 = pd.read_html('https://www.bbc.com/news/world-51235105')

# %%
pd11
# Out:
# [              Country  Deaths  Death rate*  Total Cases  \
#  0                  US  706709        216.1     43953432
#  1              Brazil  599810        286.3     21532558
#  2               India  450127         33.3     33915569
#  3              Mexico  281121        222.8      3707234
#  4              Russia  209752        143.9      7575825
#  ..                ...     ...          ...          ...
#  213             Palau       0          0.0            5
#  214  Marshall Islands       0          0.0            4
#  215             Samoa       0          0.0            3
#  216          Kiribati       0          0.0            2
#  217        Micronesia       0          0.0            1
#
#       New Cases  0  10  100  1k  10k  **  Unnamed: 5
#  0                                   NaN         NaN
#  1                                   NaN         NaN
#  2                                   NaN         NaN
#  3                                   NaN         NaN
# ...

# %%
pd11[0]
# Out:
#               Country  Deaths  Death rate*  Total Cases  \
# 0                  US  706709        216.1     43953432
# 1              Brazil  599810        286.3     21532558
# 2               India  450127         33.3     33915569
# 3              Mexico  281121        222.8      3707234
# 4              Russia  209752        143.9      7575825
# ..                ...     ...          ...          ...
# 213             Palau       0          0.0            5
# 214  Marshall Islands       0          0.0            4
# 215             Samoa       0          0.0            3
# 216          Kiribati       0          0.0            2
# 217        Micronesia       0          0.0            1
#
#      New Cases  0  10  100  1k  10k  **  Unnamed: 5
# 0                                   NaN         NaN
# 1                                   NaN         NaN
# 2                                   NaN         NaN
# 3                                   NaN         NaN
# ...

# %% [markdown]
# ### SQL

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# %%
temp_db = create_engine('sqlite:///:memory:')

# %%
temp_db.table_names()
# Out:
# /var/folders/8h/k9jsy58x1213yy3fgg122yf80000gn/T/ipykernel_65786/1744302080.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   temp_db.table_names()
# []

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/World_population')

# %%
pop = tables[5]
pop
# Out:
#    Rank      Country  Population  Area(km2)  Density(pop/km2)
# 0     1    Singapore     5704000        710              8033
# 1     2   Bangladesh   172210000     143998              1196
# 2     3    Palestine     5266785       6020               847
# 3     4      Lebanon     6856000      10452               656
# 4     5       Taiwan    23604000      36193               652
# 5     6  South Korea    51781000      99538               520
# 6     7       Rwanda    12374000      26338               470
# 7     8        Haiti    11578000      27065               428
# 8     9  Netherlands    17690000      41526               426
# 9    10       Israel     9470000      22072               429

# %%
pop.to_sql(name='population', con=temp_db)

# %%
temp_db.table_names()
# Out:
# /var/folders/8h/k9jsy58x1213yy3fgg122yf80000gn/T/ipykernel_65786/1744302080.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   temp_db.table_names()
# ['population']

# %%
pd.read_sql(sql='population', con=temp_db)
# Out:
#    index  Rank      Country  Population  Area(km2)  Density(pop/km2)
# 0      0     1    Singapore     5704000        710              8033
# 1      1     2   Bangladesh   172210000     143998              1196
# 2      2     3    Palestine     5266785       6020               847
# 3      3     4      Lebanon     6856000      10452               656
# 4      4     5       Taiwan    23604000      36193               652
# 5      5     6  South Korea    51781000      99538               520
# 6      6     7       Rwanda    12374000      26338               470
# 7      7     8        Haiti    11578000      27065               428
# 8      8     9  Netherlands    17690000      41526               426
# 9      9    10       Israel     9470000      22072               429

# %%
pd.read_sql_query(sql='select Country, Population from population', con=temp_db)
# Out:
#        Country  Population
# 0    Singapore     5704000
# 1   Bangladesh   172210000
# 2    Palestine     5266785
# 3      Lebanon     6856000
# 4       Taiwan    23604000
# 5  South Korea    51781000
# 6       Rwanda    12374000
# 7        Haiti    11578000
# 8  Netherlands    17690000
# 9       Israel     9470000
