# %% [markdown]
# # DATA VISUALIZATION WITH SEABORN

# %% [markdown]
# ### Introduction to Seaborn and Scatter Plots

# %% [markdown]
# ```
# Seaborn is a Python data visualization library based on Matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics. The main advantages of Seaborn are:
#
# It works well with Pandas data DataFrame objects,
# It has beautiful default styles,
# Due to built on Matplotlib it can be used together with Matplotlib commands,
# Easy to use.
# ```

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x = [10,20,30,40]
y = [0,15,10,25]

# %%
plt.plot(x,y)
plt.show()

# %%
sns.set() # bu komut ile matplotlib'deki bazi parametreleri seaborn'a gore update ediyoruz.

# %%
plt.plot(x,y);

# %%
sns.set_style('whitegrid')

# %%
plt.plot(x,y);

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.3.2'

# %%
sns.__version__
# Out:
# '0.11.0'

# %%
# seaborn matplotlib'deki rc parameters yani run commands'i update ediyor

# %%
cars = sns.load_dataset('mpg')

# %%
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %%
cars.dropna(inplace=True)

# %%
cars.shape
# Out:
# (392, 9)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.relplot(x='model_year', y='mpg', col='origin', hue='cylinders', data=cars)

# %% [markdown]
# #### Scatter Plot

# %%
dia = sns.load_dataset('diamonds')

# %%
dia.shape
# Out:
# (53940, 10)

# %%
dia.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
dia2 = dia[dia.cut.isin(['Premium', 'Good']) & dia.color.isin(['D', 'F', 'J'])].sample(n=100, random_state=22)

# %%
dia2.shape
# Out:
# (100, 10)

# %%
import warnings;
warnings.filterwarnings('ignore')

# %%
sns.set_style('dark')

# %%
sns.scatterplot(dia2.carat, dia2.price);

# %%
sns.scatterplot(x='carat', y='price', data=dia2);

# %%
sns.scatterplot(x='x', y='y', data=dia2);

# %%
sns.set_style('dark')

# %%
sns.scatterplot(x='carat', y='price', hue='cut', data=dia2);

# %%
sns.scatterplot(x='carat', y='price', hue='cut', palette='Purples_r', data=dia2);

# %%
sns.scatterplot(x='carat', y='price', hue='depth', data=dia2);

# %%
sns.scatterplot(x='carat', y='price', s=100, data=dia2);

# %%
sns.scatterplot(x='carat', y='price', s=50, style='cut', data=dia2);

# %%
sns.scatterplot(x='carat', y='price', s=100, size='cut', data=dia2);

# %%
# yani hue, size, style var

# %%
sns.scatterplot(x='carat', y='price', size='cut', sizes=[100, 50, 30, 20, 10], data=dia2);

# %%
# sizes belirlenirken kac tane kategori var ise o sayida sayi listeye eklenmelidir

# %%
sns.scatterplot(x='carat', y='price', size='depth', data=dia2);

# %%
sns.scatterplot(x='carat', y='price', hue='cut', style='cut', data=dia2);

# %%
sns.scatterplot(x='carat', y='price', hue='cut', style='depth', data=dia2);

# %%
sns.scatterplot(x='carat', y='price', hue='cut', style='color', data=dia2);

# %%
sns.scatterplot(x='carat', y='price', s=100, alpha=0.6, data=dia2);
# alpha 0 ile 1 arasinda, 0 saydam 1 koyu

# %%
sns.scatterplot(x='carat', y='price', marker='*', s=200, data=dia2);

# %%
sns.scatterplot(x='carat', y='price', marker='*', s=200, edgecolor='black', data=dia2);

# %% [markdown]
# ```
# Q: Which library would you prefer for plotting in Python language: Seaborn or Matplotlib?
# A: Matplotlib is the python library used for plotting but it needs lot of fine-tuning to ensure that the plots look shiny. Seaborn helps data scientists create statistically and aesthetically appealing meaningful plots. The answer to this question varies based on the requirements for plotting data.
# ```

# %% [markdown]
# ### Distribution Plots

# %% [markdown]
# #### Histogram

# %%
pen = sns.load_dataset('penguins')

# %%
pen.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
pen.shape
# Out:
# (344, 7)

# %%
pen.dropna(inplace=True)

# %%
pen.shape
# Out:
# (333, 7)

# %%
sns.set_style('darkgrid')

# %%
sns.histplot(pen.bill_length_mm);

# %%
sns.histplot(x='bill_length_mm', data=pen);

# %%
sns.histplot(y='bill_length_mm', data=pen);

# %%
sns.histplot(x='bill_length_mm', kde=True, data=pen);

# %%
sns.histplot(x='bill_length_mm', kde=True, bins=20, data=pen);

# %%
sns.histplot(x='bill_length_mm', bins=[30, 40, 45, 50, 60], data=pen);

# %%
sns.histplot(x='bill_length_mm', binwidth=10, binrange=(30,60), data=pen);

# %%
sns.histplot(x='bill_length_mm', binwidth=5, binrange=(30,60), data=pen);

# %%
sns.histplot(x='bill_length_mm', stat='count', data=pen);
# her bir bar icin count degerini veriyor

# %%
sns.histplot(x='bill_length_mm', stat='density', data=pen);
# x ve y'deki degerleri carpiminin her bar icin degeri toplandiginda 1'i veriyor

# %%
sns.histplot(x='bill_length_mm', stat='probability', data=pen);
# bir penguin'in her bir barda bulunma olasiligini veriyor
# barlarin toplam probability'si 1 olmali

# %%
sns.histplot(x='bill_length_mm', stat='probability', fill=False, data=pen);

# %%
sns.histplot(x='bill_length_mm', stat='probability', fill=False, element='step', data=pen);

# %%
sns.histplot(x='bill_length_mm', stat='probability', fill=False, element='step', cumulative=True, data=pen);

# %%
sns.histplot(x='bill_length_mm', hue='species', data=pen);

# %%
sns.histplot(x='bill_length_mm', hue='species', element='step', data=pen);

# %%
sns.histplot(x='bill_length_mm', hue='species', element='poly', data=pen);

# %%
sns.histplot(x='bill_length_mm', hue='species', multiple='layer', data=pen);

# %%
sns.histplot(x='bill_length_mm', hue='species', multiple='stack', data=pen);

# %%
sns.histplot(x='bill_length_mm', hue='species', multiple='fill', data=pen);
# birinci sutunun yuzde yuzu adelie turu, ama sekizinci sutunun yarisi gentoo iken diger yarisi chinstrap

# %%
sns.set_style('white')

# %%
sns.histplot(x='bill_length_mm', y='bill_depth_mm', data=pen);

# %%
sns.histplot(x='bill_length_mm', y='bill_depth_mm', cbar=True, data=pen);
# mesela ortadaki koyu mavi rengin oldugu yerde 16 tane penguen bulunuyor chart'a gore
# yani length'i 40 olan ve depth'i 18 olan 16 tane penguen var

# %%
sns.histplot(x='bill_length_mm', y='bill_depth_mm', hue='species', cbar=True, data=pen);

# %%
sns.histplot(x='bill_length_mm', y='species', hue='species', data=pen);

# %%
sns.histplot(x='species', hue='sex', data=pen);

# %%
# yukarida renkler ust uste cakistigi icin ayristirilamiyor, bu sebeple sutunlari yan yana koymasi icin dodge kullan
sns.histplot(x='species', hue='sex', multiple='dodge', data=pen);

# %%
sns.histplot(x='species', hue='sex', multiple='dodge', shrink=0.8, data=pen);

# %%
sns.histplot(x='species', hue='sex', multiple='dodge', shrink=0.8, palette='bone', data=pen);

# %%
sns.histplot(x='species', fill=False, data=pen)
# Out:
# <AxesSubplot:xlabel='species', ylabel='Count'>

# %% [markdown]
# #### Distplot

# %%
cars = sns.load_dataset('mpg').dropna()

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.set_style('white')

# %%
sns.displot(x='weight', data=cars);

# %%
sns.displot(x='weight', kde=True, data=cars);

# %%
sns.displot(x='weight', kind='kde', data=cars);

# %%
sns.displot(x='weight', kind='ecdf', data=cars);
# ecdf stands for empirical cumulative distribution function

# %%
sns.displot(x='weight', kind='kde', rug=True, data=cars);

# %%
sns.displot(x='weight', hue='origin', data=cars);

# %%
sns.displot(x='weight', hue='origin', kind='kde', data=cars);

# %%
sns.displot(x='weight', y='horsepower', data=cars);
# aslinda bir heatmap olusuyor. Arabalarin buyuk cogunlugu 2000 kg ve 75 beygirden kucuk.

# %%
sns.displot(x='weight', y='horsepower', kind='kde', data=cars);

# %%
sns.displot(x='weight', y='horsepower', kind='kde', rug=True, data=cars);

# %%
sns.displot(x='weight', hue='origin', col='origin', data=cars);

# %%
sns.displot(x='weight', hue='origin', col='origin', kind='kde', data=cars);

# %%
sns.displot(x='weight', hue='origin', col='origin', kind='kde', rug=True, data=cars);

# %%
sns.displot(x='weight', data=cars[cars.cylinders.isin([4,6,8])], col='origin', row='cylinders', hue='cylinders');

# %%
sns.displot(x='weight', hue='origin', col='origin', palette='crest', data=cars);

# %%
sns.displot(x='weight', hue='origin', col='origin', height=2, data=cars);
# default height = 5

# %%
sns.displot(x='weight', hue='origin', col='origin', height=2, aspect=1.5, data=cars);
# default aspect = 1

# %%
sns.displot(x='weight', data=cars, bins=20);

# %%
sns.displot(x='weight', data=cars, kind='kde', fill=True);

# %%
sns.displot(x='weight', data=cars, kind='kde', fill=True, lw=3);

# %%
sns.displot(x='weight', data=cars, kind='kde', rug=True, rug_kws={'height': 0.05, 'color': 'g'});

# %%
sns.displot(x='weight', data=cars, col='origin', facet_kws={'despine': False});
# despine ile cerceve ciziyor. Default'u True

# %%
g = sns.displot(x='weight', data=cars, col='origin')

# %%
type(g)
# g is a facetgrid object
# Out:
# seaborn.axisgrid.FacetGrid

# %%
g.axes_dict.items()
# Out:
# dict_items([('usa', <AxesSubplot:title={'center':'origin = usa'}, xlabel='weight', ylabel='Count'>), ('japan', <AxesSubplot:title={'center':'origin = japan'}, xlabel='weight'>), ('europe', <AxesSubplot:title={'center':'origin = europe'}, xlabel='weight'>)])

# %%
g = sns.displot(x='weight', data=cars, col='origin')
for col_val, ax in g.axes_dict.items():
    if col_val == 'europe':
        ax.set_facecolor('#E2F2FF')

# %% [markdown]
# #### Kernel Density Estimation (KDE) Plot

# %% [markdown]
# ```
# A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset, analagous to a histogram. KDE represents the data using a continuous probability density curve in one or more dimensions.
#
# Relative to a histogram, KDE can produce a plot that is less cluttered and more interpretable, especially when drawing multiple distributions. But it has the potential to introduce distortions if the underlying distribution is bounded or not smooth. Like a histogram, the quality of the representation also depends on the selection of good smoothing parameters.
# ```

# %%
# default olara seaborn gaussian distribution kullaniyor kde icin

# %%
cars.shape
# Out:
# (392, 9)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.kdeplot(cars.horsepower);

# %%
sns.kdeplot(cars.horsepower, shade=True);

# %%
sns.kdeplot(cars.horsepower, bw=0.5);

# %%
sns.kdeplot(cars.horsepower, bw=0.01);
# bw kucuk tutulursa farkli modlari gorme imkani da artacaktir
#

# %%
sns.kdeplot(cars.horsepower, cumulative=True);
# pdf - probability density function
# cdf - cumulative density function

# %%
sns.kdeplot(cars.horsepower, cars.mpg);

# %%
sns.kdeplot(cars.horsepower, cars.mpg, n_levels=20);

# %%
sns.kdeplot(cars.horsepower, cars.mpg, shade=True);

# %%
sns.set_style('white')

sns.kdeplot(cars.horsepower, cars.mpg, shade=True, shade_lowest=False);

# %%
sns.set_style('white')

sns.kdeplot(cars.horsepower, cars.mpg, shade=True, shade_lowest=False, cbar=True);
